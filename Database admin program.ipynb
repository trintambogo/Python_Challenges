# %%
print('Example 1 Output')
print('\nWelcome to the Database Admin Program')

credentials = {'mooman74':'alskes145','meramo1986':'kehns010101',
              'nickyD':' world1star','george2':'booo3oha',
              'admin00':'admin1234'}

username = input('Enter your username: ')

for key,value in credentials.items():
    if username == key:
        password = input('Enter your password: ')
        if password == value:
            if username == 'admin00':
                print(f'\nHello {username}! You are logged in!')
                print('\nHere is your current user database')
                for key,value in credentials.items():
                    print(f'Username : {key} \t Password: {value}')
            else:
                print(f'\nHello {username}! You are logged in!')
                change = input('Would you like to change your password: ').lower()
                if change == 'yes':
                    new_password = input('What would you like your new password to be: ')
                    if len(new_password) >= 8:
                        credentials[key] = new_password
                        print(f'\n{username} your password is {new_password}')
                    else:
                        print(f'{new_password} does not have the minimum eight characters.')
                        print(f'\n{key} your password is {value}')
        else:
            print(f'Password is incorrect!')
            break
    elif username not in credentials.keys():
        print(f'Username not in database, goodbye.')
        break
# Out:
# Example 1 Output
#
# Welcome to the Database Admin Program
# Enter your username: admin00
# Enter your password: admin1234
#
# Hello admin00! You are logged in!
#
# Here is your current user database
# Username : mooman74 	 Password: alskes145
# Username : meramo1986 	 Password: kehns010101
# Username :  nickyD 	 Password:  world1star
# Username : george2 	 Password: booo3oha
# Username : admin00 	 Password: admin1234

# %%
print('Example 2 Output')
print('\nWelcome to the Database Admin Program')

credentials = {'mooman74':'alskes145','meramo1986':'kehns010101',
              ' nickyD':' world1star','george2':'booo3oha',
              'admin00':'admin1234'}

username = input('Enter your username: ')

for key,value in credentials.items():
    if username == key:
        password = input('Enter your password: ')
        if password == value:
            if username == 'admin00':
                print(f'\nHello {username}! You are logged in!')
                print('\nHere is your current user database')
                for key,value in credentials.items():
                    print(f'Username : {key} \t Password: {value}')
            else:
                print(f'\nHello {username}! You are logged in!')
                change = input('Would you like to change your password: ').lower()
                if change == 'yes':
                    new_password = input('What would you like your new password to be: ')
                    if len(new_password) >= 8:
                        credentials[key] = new_password
                        print(f'\n{username} your password is {new_password}')
                    else:
                        print(f'{new_password} does not have the minimum eight characters.')
                        print(f'\n{key} your password is {value}')
        else:
            print(f'Password is incorrect!')
            break
    elif username not in credentials.keys():
        print(f'Username not in database, goodbye.')
        break
# Out:
# Example 2 Output
#
# Welcome to the Database Admin Program
# Enter your username: george2
# Enter your password: booo3oha
#
# Hello george2! You are logged in!
# Would you like to change your password: yes
# What would you like your new password to be: 12345678
#
# george2 your password is 12345678

# %%
print('Example 3 Output')
print('\nWelcome to the Database Admin Program')

credentials = {'mooman74':'alskes145','meramo1986':'kehns010101',
              'nickyD':'world1star','george2':'booo3oha',
              'admin00':'admin1234'}

username = input('Enter your username: ')

for key,value in credentials.items():
    if username == key:
        password = input('Enter your password: ')
        if password == value:
            if username == 'admin00':
                print(f'\nHello {username}! You are logged in!')
                print('\nHere is your current user database')
                for key,value in credentials.items():
                    print(f'Username : {key} \t Password: {value}')
            else:
                print(f'\nHello {username}! You are logged in!')
                change = input('Would you like to change your password: ').lower()
                if change == 'yes':
                    new_password = input('What would you like your new password to be: ')
                    if len(new_password) >= 8:
                        credentials[key] = new_password
                        print(f'\n{username} your password is {new_password}')
                    else:
                        print(f'{new_password} does not have the minimum eight characters.')
                        print(f'\n{key} your password is {value}')
        else:
            print(f'Password is incorrect!')
            break
    elif username not in credentials.keys():
        print(f'Username not in database, goodbye.')
        break
# Out:
# Example 3 Output
#
# Welcome to the Database Admin Program
# Enter your username: nickyD
# Enter your password: world1star
#
# Hello nickyD! You are logged in!
# Would you like to change your password: yes
# What would you like your new password to be: help
# help does not have the minimum eight characters.
#
# nickyD your password is world1star

# %%
print('Example 4 Output')
print('\nWelcome to the Database Admin Program')

credentials = {'mooman74':'alskes145','meramo1986':'kehns010101',
              'nickyD':'world1star','george2':'booo3oha',
              'admin00':'admin1234'}

username = input('Enter your username: ')

for key,value in credentials.items():
    if username == key:
        password = input('Enter your password: ')
        if password == value:
            if username == 'admin00':
                print(f'\nHello {username}! You are logged in!')
                print('\nHere is your current user database')
                for key,value in credentials.items():
                    print(f'Username : {key} \t Password: {value}')
            else:
                print(f'\nHello {username}! You are logged in!')
                change = input('Would you like to change your password: ').lower()
                if change == 'yes':
                    new_password = input('What would you like your new password to be: ')
                    if len(new_password) >= 8:
                        credentials[key] = new_password
                        print(f'\n{username} your password is {new_password}')
                    else:
                        print(f'{new_password} does not have the minimum eight characters.')
                        print(f'\n{key} your password is {value}')
        else:
            print(f'Password is incorrect!')
            break
    elif username not in credentials.keys():
        print(f'Username not in database, goodbye.')
        break
# Out:
# Example 4 Output
#
# Welcome to the Database Admin Program
# Enter your username: george2
# Enter your password: happy
# Password is incorrect!

# %%
print('Example 5 Output')
print('\nWelcome to the Database Admin Program')

credentials = {'mooman74':'alskes145','meramo1986':'kehns010101',
              'nickyD':'world1star','george2':'booo3oha',
              'admin00':'admin1234'}

username = input('Enter your username: ')

for key,value in credentials.items():
    if username == key:
        password = input('Enter your password: ')
        if password == value:
            if username == 'admin00':
                print(f'\nHello {username}! You are logged in!')
                print('\nHere is your current user database')
                for key,value in credentials.items():
                    print(f'Username : {key} \t Password: {value}')
            else:
                print(f'\nHello {username}! You are logged in!')
                change = input('Would you like to change your password: ').lower()
                if change == 'yes':
                    new_password = input('What would you like your new password to be: ')
                    if len(new_password) >= 8:
                        credentials[key] = new_password
                        print(f'\n{username} your password is {new_password}')
                    else:
                        print(f'{new_password} does not have the minimum eight characters.')
                        print(f'\n{key} your password is {value}')
        else:
            print(f'Password is incorrect!')
            break
    elif username not in credentials.keys():
        print(f'Username not in database, goodbye.')
        break
# Out:
# Example 5 Output
#
# Welcome to the Database Admin Program
# Enter your username: emma
# Username not in database, goodbye.
